# %%
from langchain_community.tools import DuckDuckGoSearchRun
# Out:
# /Users/triptibhardwaj/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
from datetime import date
user_query = input("Enter query: ")
today = date.today().strftime("%B %d, %Y")
query = f"{user_query} {today}"
results = search_tool.invoke(query)

# %%
results
# Out:
# "Bhabha's Third Space is the space in which hybrid cultural forms and identities exist. In his theories, the term hybrid describes new cultural forms that emerge through the interaction between colonizer and … Jun 10, 2026 · Get the latest space exploration, innovation and astronomy news. Space.com celebrates humanity's ongoing expansion across the final frontier. Indian National Space Promotion and Authorization Centre (IN-SPACe), an autonomous single-window nodal agency in the Department of Space (DOS) is promoting, enabling, authorizing and supervising … 2 days ago · Indian Space Research Organisation (ISRO) is the space agency of India. The organisation is involved in science, engineering and technology to harvest the benefits. Jun 27, 1997 · Space.com is your source for the latest astronomy news and space discoveries, live coverage of space flights and the science of space travel. | Space"

# %%
search_tool
# Out:
# DuckDuckGoSearchRun(api_wrapper=DuckDuckGoSearchAPIWrapper(region='wt-wt', safesearch='moderate', time='y', max_results=5, backend='auto', source='text'))
